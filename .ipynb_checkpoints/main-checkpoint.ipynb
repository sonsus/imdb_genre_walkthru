# %%
from parser import *
import json

# %%
bigger_wrapper = {}
genre_dict_list= []

# %%
with open("split_list.txt", "r") as split_list:
    raw_keys_list = split_list.readlines()
    keys_list = [raw_key.split(".")[0] for i,raw_key in enumerate(raw_keys_list)]
len(keys_list)
# Out:
# 408

# %%
data_dict = {}
for moviekey in keys_list:
    if moviekey in data_dict.keys(): 
        exit("moviekey duplicate!= {}".format(moviekey))
    movieinfo = MovieInfo(moviekey)
    data_dict[moviekey] = movieinfo.key_title_yr_genre_runtime()
    genre_dict_list += data_dict[moviekey]["genre_list"]
    print(data_dict[moviekey])
# Out:
# {'key': 'tt0034583', 'title': 'Casablanca ', 'year': '1942', 'genre_list': ['Drama', 'Romance', 'War'], 'running_time': 102}
# {'key': 'tt0036775', 'title': 'Double Indemnity ', 'year': '1944', 'genre_list': ['Crime', 'Drama', 'Film-Noir'], 'running_time': 107}
# {'key': 'tt0056923', 'title': 'Charade ', 'year': '1963', 'genre_list': ['Comedy', 'Mystery', 'Romance'], 'running_time': 113}
# {'key': 'tt0061722', 'title': 'The Graduate ', 'year': '1967', 'genre_list': ['Comedy', 'Drama', 'Romance'], 'running_time': 106}
# {'key': 'tt0068646', 'title': 'Daeboo ', 'year': '1972', 'genre_list': ['Crime', 'Drama'], 'running_time': 175}
# {'key': 'tt0071315', 'title': 'Chinatown ', 'year': '1974', 'genre_list': ['Drama', 'Mystery', 'Thriller'], 'running_time': 130}
# {'key': 'tt0071562', 'title': 'The Godfather: Part II ', 'year': '1974', 'genre_list': ['Crime', 'Drama'], 'running_time': 202}
# {'key': 'tt0074285', 'title': 'Carrie ', 'year': '1976', 'genre_list': ['Horror'], 'running_time': 98}
# {'key': 'tt0075314', 'title': 'Taxi Driver ', 'year': '1976', 'genre_list': ['Crime', 'Drama'], 'running_time': 114}
# {'key': 'tt0076759', 'title': 'Star Wars ', 'year': '1977', 'genre_list': ['Action', 'Adventure', 'Fantasy'], 'running_time': 121}
# {'key': 'tt0080684', 'title': 'Star Wars: Episode V - The Empire Strikes Back ', 'year': '1980', 'genre_list': ['Action', 'Adventure', 'Fantasy'], 'running_time': 124}
# {'key': 'tt0082198', 'title': 'Conan the Barbarian ', 'year': '1982', 'genre_list': ['Adventure', 'Fantasy'], 'running_time': 129}
# {'key': 'tt0082971', 'title': 'Raiders of the Lost Ark ', 'year': '1981', 'genre_list': ['Action', 'Adventure'], 'running_time': 115}
# {'key': 'tt0083658', 'title': 'Blade Runner ', 'year': '1982', 'genre_list': ['Sci-Fi', 'Thriller'], 'running_time': 117}
# {'key': 'tt0083866', 'title': 'E.T. the Extra-Terrestrial ', 'year': '1982', 'genre_list': ['Family', 'Sci-Fi'], 'running_time': 115}
# {'key': 'tt0083987', 'title': 'Gandhi ', 'year': '1982', 'genre_list': ['Biography', 'Drama', 'History'], 'running_time': 191}
# {'key': 'tt0086190', 'title': 'Star Wars: Episode VI - Return of the Jedi ', 'year': '1983', 'genre_list': ['Action', 'Adventure', 'Fantasy'], 'running_time': 131}
# {'key': 'tt0086879', 'title': 'Amadeus ', 'year': '1984', 'genre_list': ['Biography', 'Drama', 'History'], 'running_time': 160}
# {'key': 'tt0087469', 'title': 'Indiana Jones and the Temple of Doom ', 'year': '1984', 'genre_list': ['Action', 'Adventure'], 'running_time': 118}
# {'key': 'tt0087892', 'title': 'A Passage to India ', 'year': '1984', 'genre_list': ['Adventure', 'Drama', 'History'], 'running_time': 164}
# {'key': 'tt0088763', 'title': 'Back to the Future ', 'year': '1985', 'genre_list': ['Adventure', 'Comedy', 'Sci-Fi'], 'running_time': 116}
# {'key': 'tt0089218', 'title': 'The Goonies ', 'year': '1985', 'genre_list': ['Adventure', 'Comedy', 'Family'], 'running_time': 114}
# {'key': 'tt0090756', 'title': 'Blue Velvet ', 'year': '1986', 'genre_list': ['Drama', 'Mystery', 'Thriller'], 'running_time': 120}
# {'key': 'tt0091042', 'title': "Ferris Bueller's Day Off ", 'year': '1986', 'genre_list': ['Comedy'], 'running_time': 103}
# {'key': 'tt0091867', 'title': 'A Room with a View ', 'year': '1985', 'genre_list': ['Drama', 'Romance'], 'running_time': 117}
# {'key': 'tt0094721', 'title': 'Beetlejuice ', 'year': '1988', 'genre_list': ['Comedy', 'Fantasy'], 'running_time': 92}
# {'key': 'tt0095953', 'title': 'Rain Man ', 'year': '1988', 'genre_list': ['Drama'], 'running_time': 133}
# {'key': 'tt0096320', 'title': 'Twins ', 'year': '1988', 'genre_list': ['Comedy', 'Crime'], 'running_time': 107}
# {'key': 'tt0096446', 'title': 'Willow ', 'year': '1988', 'genre_list': ['Action', 'Adventure', 'Drama'], 'running_time': 126}
# {'key': 'tt0096874', 'title': 'Back to the Future Part II ', 'year': '1989', 'genre_list': ['Adventure', 'Comedy', 'Sci-Fi'], 'running_time': 108}
# {'key': 'tt0096895', 'title': 'Batman ', 'year': '1989', 'genre_list': ['Action', 'Adventure'], 'running_time': 126}
# {'key': 'tt0097165', 'title': 'Dead Poets Society ', 'year': '1989', 'genre_list': ['Comedy', 'Drama'], 'running_time': 128}
# {'key': 'tt0097576', 'title': 'Indiana Jones and the Last Crusade ', 'year': '1989', 'genre_list': ['Action', 'Adventure', 'Fantasy'], 'running_time': 127}
# {'key': 'tt0098635', 'title': 'When Harry Met Sally... ', 'year': '1989', 'genre_list': ['Comedy', 'Drama', 'Romance'], 'running_time': 96}
# {'key': 'tt0099487', 'title': 'Edward Scissorhands ', 'year': '1990', 'genre_list': ['Drama', 'Fantasy', 'Romance'], 'running_time': 105}
# {'key': 'tt0099653', 'title': 'Ghost ', 'year': '1990', 'genre_list': ['Drama', 'Fantasy', 'Romance'], 'running_time': 127}
# {'key': 'tt0099674', 'title': 'The Godfather: Part III ', 'year': '1990', 'genre_list': ['Crime', 'Drama'], 'running_time': 162}
# {'key': 'tt0099685', 'title': 'Goodfellas ', 'year': '1990', 'genre_list': ['Crime', 'Drama'], 'running_time': 146}
# {'key': 'tt0100405', 'title': 'Pretty Woman ', 'year': '1990', 'genre_list': ['Comedy', 'Romance'], 'running_time': 119}
# {'key': 'tt0101393', 'title': 'Backdraft ', 'year': '1991', 'genre_list': ['Action', 'Crime', 'Drama'], 'running_time': 137}
# {'key': 'tt0102798', 'title': 'Robin Hood: Prince of Thieves ', 'year': '1991', 'genre_list': ['Action', 'Adventure', 'Drama'], 'running_time': 143}
# {'key': 'tt0103064', 'title': 'Terminator 2: Judgment Day ', 'year': '1991', 'genre_list': ['Action', 'Sci-Fi'], 'running_time': 137}
# {'key': 'tt0104036', 'title': 'The Crying Game ', 'year': '1992', 'genre_list': ['Crime', 'Drama', 'Romance'], 'running_time': 112}
# {'key': 'tt0104257', 'title': 'A Few Good Men ', 'year': '1992', 'genre_list': ['Drama', 'Thriller'], 'running_time': 138}
# {'key': 'tt0105414', 'title': 'Single White Female ', 'year': '1992', 'genre_list': ['Drama', 'Thriller'], 'running_time': 107}
# {'key': 'tt0106918', 'title': 'The Firm ', 'year': '1993', 'genre_list': ['Drama', 'Mystery', 'Thriller'], 'running_time': 154}
# {'key': 'tt0107048', 'title': 'Groundhog Day ', 'year': '1993', 'genre_list': ['Comedy', 'Fantasy', 'Romance'], 'running_time': 101}
# {'key': 'tt0107290', 'title': 'Jyuragi gongwon ', 'year': '1993', 'genre_list': ['Adventure', 'Sci-Fi', 'Thriller'], 'running_time': 127}
# {'key': 'tt0107614', 'title': 'Mrs. Doubtfire ', 'year': '1993', 'genre_list': ['Comedy', 'Drama', 'Family'], 'running_time': 125}
# {'key': 'tt0108052', 'title': "Schindler's List ", 'year': '1993', 'genre_list': ['Biography', 'Drama', 'History'], 'running_time': 195}
# {'key': 'tt0108160', 'title': 'Sleepless in Seattle ', 'year': '1993', 'genre_list': ['Comedy', 'Drama', 'Romance'], 'running_time': 105}
# {'key': 'tt0108185', 'title': 'Sommersby ', 'year': '1993', 'genre_list': ['Drama', 'Mystery', 'Romance'], 'running_time': 114}
# {'key': 'tt0108399', 'title': 'True Romance ', 'year': '1993', 'genre_list': ['Crime', 'Drama', 'Romance'], 'running_time': 119}
# {'key': 'tt0109445', 'title': 'Clerks ', 'year': '1994', 'genre_list': ['Comedy'], 'running_time': 92}
# {'key': 'tt0109446', 'title': 'The Client ', 'year': '1994', 'genre_list': ['Crime', 'Drama', 'Mystery'], 'running_time': 119}
# {'key': 'tt0109830', 'title': 'Forrest Gump ', 'year': '1994', 'genre_list': ['Drama', 'Romance'], 'running_time': 142}
# {'key': 'tt0109831', 'title': 'Four Weddings and a Funeral ', 'year': '1994', 'genre_list': ['Comedy', 'Drama', 'Romance'], 'running_time': 117}
# {'key': 'tt0110912', 'title': 'Pulp Fiction ', 'year': '1994', 'genre_list': ['Crime', 'Drama'], 'running_time': 154}
# {'key': 'tt0110950', 'title': 'Reality Bites ', 'year': '1994', 'genre_list': ['Comedy', 'Drama', 'Romance'], 'running_time': 99}
# {'key': 'tt0111161', 'title': 'The Shawshank Redemption ', 'year': '1994', 'genre_list': ['Drama'], 'running_time': 142}
# {'key': 'tt0112384', 'title': 'Apollo 13 ', 'year': '1995', 'genre_list': ['Adventure', 'Drama', 'History'], 'running_time': 140}
# {'key': 'tt0112573', 'title': 'Braveheart ', 'year': '1995', 'genre_list': ['Biography', 'Drama', 'History'], 'running_time': 178}
# {'key': 'tt0112681', 'title': 'Citizen X ', 'year': '1995', 'genre_list': ['Biography', 'Crime', 'Drama'], 'running_time': 105}
# {'key': 'tt0112697', 'title': 'Clueless ', 'year': '1995', 'genre_list': ['Comedy', 'Romance'], 'running_time': 97}
# {'key': 'tt0112740', 'title': 'Crimson Tide ', 'year': '1995', 'genre_list': ['Action', 'Drama', 'Thriller'], 'running_time': 116}
# {'key': 'tt0112818', 'title': 'Dead Man Walking ', 'year': '1995', 'genre_list': ['Crime', 'Drama'], 'running_time': 122}
# {'key': 'tt0113161', 'title': 'Get Shorty ', 'year': '1995', 'genre_list': ['Comedy', 'Crime', 'Thriller'], 'running_time': 105}
# {'key': 'tt0113243', 'title': 'Hackers ', 'year': '1995', 'genre_list': ['Comedy', 'Crime', 'Drama'], 'running_time': 107}
# {'key': 'tt0113497', 'title': 'Jumanji ', 'year': '1995', 'genre_list': ['Adventure', 'Family', 'Fantasy'], 'running_time': 104}
# {'key': 'tt0114709', 'title': 'Toy Story ', 'year': '1995', 'genre_list': ['Animation', 'Adventure', 'Comedy'], 'running_time': 81}
# {'key': 'tt0114814', 'title': 'The Usual Suspects ', 'year': '1995', 'genre_list': ['Crime', 'Mystery', 'Thriller'], 'running_time': 106}
# {'key': 'tt0114924', 'title': 'While You Were Sleeping ', 'year': '1995', 'genre_list': ['Comedy', 'Drama', 'Romance'], 'running_time': 103}
# {'key': 'tt0116282', 'title': 'Fargo ', 'year': '1996', 'genre_list': ['Crime', 'Drama', 'Thriller'], 'running_time': 98}
# {'key': 'tt0116629', 'title': 'Independence Day ', 'year': '1996', 'genre_list': ['Action', 'Adventure', 'Sci-Fi'], 'running_time': 145}
# {'key': 'tt0116695', 'title': 'Jerry Maguire ', 'year': '1996', 'genre_list': ['Comedy', 'Drama', 'Romance'], 'running_time': 139}
# {'key': 'tt0116908', 'title': 'The Long Kiss Goodnight ', 'year': '1996', 'genre_list': ['Action', 'Crime', 'Drama'], 'running_time': 121}
# {'key': 'tt0117381', 'title': 'Primal Fear ', 'year': '1996', 'genre_list': ['Crime', 'Drama', 'Mystery'], 'running_time': 129}
# {'key': 'tt0118556', 'title': 'Addicted to Love ', 'year': '1997', 'genre_list': ['Comedy', 'Romance'], 'running_time': 100}
# {'key': 'tt0118564', 'title': 'Affliction ', 'year': '1997', 'genre_list': ['Drama', 'Mystery', 'Thriller'], 'running_time': 114}
# {'key': 'tt0118571', 'title': 'Air Force One ', 'year': '1997', 'genre_list': ['Action', 'Drama', 'Thriller'], 'running_time': 124}
# {'key': 'tt0118617', 'title': 'Anastasia ', 'year': '1997', 'genre_list': ['Animation', 'Adventure', 'Drama'], 'running_time': 94}
# {'key': 'tt0118715', 'title': 'The Big Lebowski ', 'year': '1998', 'genre_list': ['Comedy', 'Crime'], 'running_time': 117}
# {'key': 'tt0118842', 'title': 'Chasing Amy ', 'year': '1997', 'genre_list': ['Comedy', 'Drama', 'Romance'], 'running_time': 113}
# {'key': 'tt0118971', 'title': "The Devil's Advocate ", 'year': '1997', 'genre_list': ['Drama', 'Mystery', 'Thriller'], 'running_time': 144}
# {'key': 'tt0119081', 'title': 'Event Horizon ', 'year': '1997', 'genre_list': ['Horror', 'Sci-Fi', 'Thriller'], 'running_time': 96}
# {'key': 'tt0119141', 'title': 'Fools Rush In ', 'year': '1997', 'genre_list': ['Comedy', 'Drama', 'Romance'], 'running_time': 109}
# {'key': 'tt0119282', 'title': 'Hercules ', 'year': '1997', 'genre_list': ['Animation', 'Adventure', 'Comedy'], 'running_time': 93}
# {'key': 'tt0119396', 'title': 'Jackie Brown ', 'year': '1997', 'genre_list': ['Crime', 'Drama', 'Thriller'], 'running_time': 154}
# {'key': 'tt0119488', 'title': 'L.A. Confidential ', 'year': '1997', 'genre_list': ['Crime', 'Drama', 'Mystery'], 'running_time': 138}
# {'key': 'tt0119567', 'title': 'The Lost World: Jurassic Park ', 'year': '1997', 'genre_list': ['Action', 'Adventure', 'Sci-Fi'], 'running_time': 129}
# {'key': 'tt0119643', 'title': 'Meet Joe Black ', 'year': '1998', 'genre_list': ['Drama', 'Fantasy', 'Romance'], 'running_time': 178}
# {'key': 'tt0119654', 'title': 'Men in Black ', 'year': '1997', 'genre_list': ['Adventure', 'Comedy', 'Mystery'], 'running_time': 98}
# {'key': 'tt0119822', 'title': 'As Good as It Gets ', 'year': '1997', 'genre_list': ['Comedy', 'Drama', 'Romance'], 'running_time': 139}
# {'key': 'tt0120338', 'title': 'Titanic ', 'year': '1997', 'genre_list': ['Drama', 'Romance'], 'running_time': 194}
# {'key': 'tt0120382', 'title': 'The Truman Show ', 'year': '1998', 'genre_list': ['Comedy', 'Drama', 'Sci-Fi'], 'running_time': 103}
# {'key': 'tt0120586', 'title': 'American History X ', 'year': '1998', 'genre_list': ['Crime', 'Drama'], 'running_time': 119}
# {'key': 'tt0120611', 'title': 'Blade ', 'year': '1998', 'genre_list': ['Action', 'Horror'], 'running_time': 120}
# {'key': 'tt0120623', 'title': "A Bug's Life ", 'year': '1998', 'genre_list': ['Animation', 'Adventure', 'Comedy'], 'running_time': 95}
# {'key': 'tt0120684', 'title': 'Gods and Monsters ', 'year': '1998', 'genre_list': ['Biography', 'Drama'], 'running_time': 105}
# {'key': 'tt0120689', 'title': 'The Green Mile ', 'year': '1999', 'genre_list': ['Crime', 'Drama', 'Fantasy'], 'running_time': 189}
# {'key': 'tt0120735', 'title': 'Lock, Stock and Two Smoking Barrels ', 'year': '1998', 'genre_list': ['Comedy', 'Crime'], 'running_time': 107}
# {'key': 'tt0120737', 'title': 'The Lord of the Rings: The Fellowship of the Ring ', 'year': '2001', 'genre_list': ['Adventure', 'Drama', 'Fantasy'], 'running_time': 178}
# {'key': 'tt0120762', 'title': 'Mulan ', 'year': '1998', 'genre_list': ['Animation', 'Adventure', 'Family'], 'running_time': 88}
# {'key': 'tt0120815', 'title': 'Saving Private Ryan ', 'year': '1998', 'genre_list': ['Drama', 'War'], 'running_time': 169}
# {'key': 'tt0120828', 'title': 'Six Days Seven Nights ', 'year': '1998', 'genre_list': ['Action', 'Adventure', 'Comedy'], 'running_time': 98}
# {'key': 'tt0120888', 'title': 'The Wedding Singer ', 'year': '1998', 'genre_list': ['Comedy', 'Music', 'Romance'], 'running_time': 100}
# {'key': 'tt0120890', 'title': 'Wild Things ', 'year': '1998', 'genre_list': ['Crime', 'Drama', 'Mystery'], 'running_time': 108}
# {'key': 'tt0120903', 'title': 'X-Men ', 'year': '2000', 'genre_list': ['Action', 'Adventure', 'Sci-Fi'], 'running_time': 104}
# {'key': 'tt0120915', 'title': 'Star Wars: Episode I - The Phantom Menace ', 'year': '1999', 'genre_list': ['Action', 'Adventure', 'Fantasy'], 'running_time': 136}
# {'key': 'tt0121765', 'title': 'Star Wars: Episode II - Attack of the Clones ', 'year': '2002', 'genre_list': ['Action', 'Adventure', 'Fantasy'], 'running_time': 142}
# {'key': 'tt0121766', 'title': 'Star Wars: Episode III - Revenge of the Sith ', 'year': '2005', 'genre_list': ['Action', 'Adventure', 'Fantasy'], 'running_time': 140}
# {'key': 'tt0125439', 'title': 'Notting Hill ', 'year': '1999', 'genre_list': ['Comedy', 'Drama', 'Romance'], 'running_time': 124}
# {'key': 'tt0127536', 'title': 'Elizabeth ', 'year': '1998', 'genre_list': ['Biography', 'Drama', 'History'], 'running_time': 124}
# {'key': 'tt0129387', 'title': "There's Something About Mary ", 'year': '1998', 'genre_list': ['Comedy', 'Romance'], 'running_time': 119}
# {'key': 'tt0133093', 'title': 'The Matrix ', 'year': '1999', 'genre_list': ['Action', 'Sci-Fi'], 'running_time': 136}
# {'key': 'tt0133152', 'title': 'Planet of the Apes ', 'year': '2001', 'genre_list': ['Action', 'Adventure', 'Sci-Fi'], 'running_time': 119}
# {'key': 'tt0137523', 'title': 'Fight Club ', 'year': '1999', 'genre_list': ['Drama'], 'running_time': 139}
# {'key': 'tt0139134', 'title': 'The Temptation More Beautiful Than a Love ', 'year': '1999', 'genre_list': ['Drama', 'Romance'], 'running_time': 97}
# {'key': 'tt0140352', 'title': 'The Insider ', 'year': '1999', 'genre_list': ['Biography', 'Drama', 'Thriller'], 'running_time': 157}
# {'key': 'tt0144084', 'title': 'American Psycho ', 'year': '2000', 'genre_list': ['Crime', 'Drama'], 'running_time': 102}
# {'key': 'tt0145734', 'title': 'Playing by Heart ', 'year': '1998', 'genre_list': ['Comedy', 'Drama', 'Romance'], 'running_time': 121}
# {'key': 'tt0146882', 'title': 'High Fidelity ', 'year': '2000', 'genre_list': ['Comedy', 'Drama', 'Music'], 'running_time': 113}
# {'key': 'tt0147800', 'title': '10 Things I Hate About You ', 'year': '1999', 'genre_list': ['Comedy', 'Drama', 'Romance'], 'running_time': 97}
# {'key': 'tt0151804', 'title': 'Office Space ', 'year': '1999', 'genre_list': ['Comedy'], 'running_time': 89}
# {'key': 'tt0161860', 'title': 'Love in Africa ', 'year': '2001', 'genre_list': ['Biography', 'Drama'], 'running_time': 141}
# {'key': 'tt0163025', 'title': 'Jurassic Park III ', 'year': '2001', 'genre_list': ['Action', 'Adventure', 'Sci-Fi'], 'running_time': 92}
# {'key': 'tt0163187', 'title': 'Runaway Bride ', 'year': '1999', 'genre_list': ['Comedy', 'Romance'], 'running_time': 116}
# {'key': 'tt0166924', 'title': 'Mulholland Dr. ', 'year': '2001', 'genre_list': ['Drama', 'Mystery', 'Thriller'], 'running_time': 147}
# {'key': 'tt0167260', 'title': 'The Lord of the Rings: The Return of the King ', 'year': '2003', 'genre_list': ['Adventure', 'Drama', 'Fantasy'], 'running_time': 201}
# {'key': 'tt0167261', 'title': 'The Lord of the Rings: The Two Towers ', 'year': '2002', 'genre_list': ['Adventure', 'Drama', 'Fantasy'], 'running_time': 179}
# {'key': 'tt0167404', 'title': 'The Sixth Sense ', 'year': '1999', 'genre_list': ['Drama', 'Mystery', 'Thriller'], 'running_time': 107}
# {'key': 'tt0169547', 'title': 'American Beauty ', 'year': '1999', 'genre_list': ['Drama'], 'running_time': 122}
# {'key': 'tt0171433', 'title': 'Keeping the Faith ', 'year': '2000', 'genre_list': ['Comedy', 'Drama', 'Romance'], 'running_time': 128}
# {'key': 'tt0172495', 'title': 'Gladiator ', 'year': '2000', 'genre_list': ['Action', 'Adventure', 'Drama'], 'running_time': 155}
# {'key': 'tt0179098', 'title': 'Moonlight Mile ', 'year': '2002', 'genre_list': ['Drama', 'Romance'], 'running_time': 117}
# {'key': 'tt0181875', 'title': 'Almost Famous ', 'year': '2000', 'genre_list': ['Adventure', 'Comedy', 'Drama'], 'running_time': 122}
# {'key': 'tt0186975', 'title': 'Down to You ', 'year': '2000', 'genre_list': ['Comedy', 'Drama', 'Romance'], 'running_time': 91}
# {'key': 'tt0200550', 'title': 'Coyote Ugly ', 'year': '2000', 'genre_list': ['Comedy', 'Drama', 'Music'], 'running_time': 100}
# {'key': 'tt0203009', 'title': 'Moulin Rouge! ', 'year': '2001', 'genre_list': ['Drama', 'Musical', 'Romance'], 'running_time': 127}
# {'key': 'tt0206634', 'title': 'Children of Men ', 'year': '2006', 'genre_list': ['Drama', 'Sci-Fi', 'Thriller'], 'running_time': 109}
# {'key': 'tt0208092', 'title': 'Snatch ', 'year': '2000', 'genre_list': ['Comedy', 'Crime'], 'running_time': 104}
# {'key': 'tt0209475', 'title': 'The Wedding Planner ', 'year': '2001', 'genre_list': ['Comedy', 'Romance'], 'running_time': 103}
# {'key': 'tt0212338', 'title': 'Meet the Parents ', 'year': '2000', 'genre_list': ['Comedy', 'Romance'], 'running_time': 108}
# {'key': 'tt0212720', 'title': 'Artificial Intelligence: AI ', 'year': '2001', 'genre_list': ['Adventure', 'Drama', 'Sci-Fi'], 'running_time': 146}
# {'key': 'tt0213149', 'title': 'Pearl Harbor ', 'year': '2001', 'genre_list': ['Action', 'Drama', 'History'], 'running_time': 183}
# {'key': 'tt0217630', 'title': 'Loser ', 'year': '2000', 'genre_list': ['Comedy', 'Romance'], 'running_time': 98}
# {'key': 'tt0218967', 'title': 'The Family Man ', 'year': '2000', 'genre_list': ['Comedy', 'Drama', 'Fantasy'], 'running_time': 125}
# {'key': 'tt0221027', 'title': 'Blow ', 'year': '2001', 'genre_list': ['Biography', 'Crime', 'Drama'], 'running_time': 124}
# {'key': 'tt0234215', 'title': 'The Matrix Reloaded ', 'year': '2003', 'genre_list': ['Action', 'Sci-Fi'], 'running_time': 138}
# {'key': 'tt0240772', 'title': "Ocean's Eleven ", 'year': '2001', 'genre_list': ['Crime', 'Thriller'], 'running_time': 116}
# {'key': 'tt0240890', 'title': 'Serendipity ', 'year': '2001', 'genre_list': ['Comedy', 'Romance'], 'running_time': 90}
# {'key': 'tt0241527', 'title': "Harry Potter and the Sorcerer's Stone ", 'year': '2001', 'genre_list': ['Adventure', 'Family', 'Fantasy'], 'running_time': 152}
# {'key': 'tt0242653', 'title': 'The Matrix Revolutions ', 'year': '2003', 'genre_list': ['Action', 'Sci-Fi'], 'running_time': 129}
# {'key': 'tt0243155', 'title': "Bridget Jones's Diary ", 'year': '2001', 'genre_list': ['Comedy', 'Drama', 'Romance'], 'running_time': 97}
# {'key': 'tt0244353', 'title': 'The Mists of Avalon             ', 'year': '2001', 'genre_list': ['Drama', 'Fantasy'], 'running_time': 183}
# {'key': 'tt0245238', 'title': 'Lost and Delirious ', 'year': '2001', 'genre_list': ['Drama', 'Romance'], 'running_time': 103}
# {'key': 'tt0246772', 'title': 'Bella Martha ', 'year': '2001', 'genre_list': ['Comedy', 'Romance', 'Drama'], 'running_time': 109}
# {'key': 'tt0250494', 'title': 'Legally Blonde ', 'year': '2001', 'genre_list': ['Comedy', 'Romance'], 'running_time': 96}
# {'key': 'tt0250797', 'title': 'Unfaithful ', 'year': '2002', 'genre_list': ['Drama', 'Thriller'], 'running_time': 124}
# {'key': 'tt0251127', 'title': 'How to Lose a Guy in 10 Days ', 'year': '2003', 'genre_list': ['Comedy', 'Romance'], 'running_time': 116}
# {'key': 'tt0256380', 'title': 'Shallow Hal ', 'year': '2001', 'genre_list': ['Comedy', 'Drama', 'Fantasy'], 'running_time': 114}
# {'key': 'tt0256415', 'title': 'Sweet Home Alabama ', 'year': '2002', 'genre_list': ['Comedy', 'Romance'], 'running_time': 108}
# {'key': 'tt0257360', 'title': 'About Schmidt ', 'year': '2002', 'genre_list': ['Comedy', 'Drama'], 'running_time': 125}
# {'key': 'tt0258463', 'title': 'The Bourne Identity ', 'year': '2002', 'genre_list': ['Action', 'Mystery', 'Thriller'], 'running_time': 119}
# {'key': 'tt0259446', 'title': 'My Big Fat Greek Wedding ', 'year': '2002', 'genre_list': ['Comedy', 'Drama', 'Romance'], 'running_time': 95}
# {'key': 'tt0268978', 'title': 'A Beautiful Mind ', 'year': '2001', 'genre_list': ['Biography', 'Drama'], 'running_time': 135}
# {'key': 'tt0270980', 'title': "My Boss's Daughter ", 'year': '2003', 'genre_list': ['Comedy', 'Romance'], 'running_time': 86}
# {'key': 'tt0276751', 'title': 'About a Boy ', 'year': '2002', 'genre_list': ['Comedy', 'Drama', 'Romance'], 'running_time': 101}
# {'key': 'tt0281358', 'title': 'A Walk to Remember ', 'year': '2002', 'genre_list': ['Drama', 'Romance'], 'running_time': 101}
# {'key': 'tt0286106', 'title': 'Signs ', 'year': '2002', 'genre_list': ['Drama', 'Mystery', 'Sci-Fi'], 'running_time': 106}
# {'key': 'tt0289043', 'title': '28 Days Later... ', 'year': '2002', 'genre_list': ['Drama', 'Horror', 'Sci-Fi'], 'running_time': 113}
# {'key': 'tt0289879', 'title': 'Nabi hyogwa ', 'year': '2004', 'genre_list': ['Sci-Fi', 'Thriller'], 'running_time': 113}
# {'key': 'tt0290002', 'title': 'Meet the Fockers ', 'year': '2004', 'genre_list': ['Comedy', 'Romance'], 'running_time': 115}
# {'key': 'tt0290334', 'title': 'X2 ', 'year': '2003', 'genre_list': ['Action', 'Adventure', 'Sci-Fi'], 'running_time': 134}
# {'key': 'tt0294357', 'title': 'Beyond Borders ', 'year': '2003', 'genre_list': ['Adventure', 'Drama', 'Romance'], 'running_time': 127}
# {'key': 'tt0295297', 'title': 'Harry Potter and the Chamber of Secrets ', 'year': '2002', 'genre_list': ['Adventure', 'Family', 'Fantasy'], 'running_time': 161}
# {'key': 'tt0298203', 'title': '8 Mile ', 'year': '2002', 'genre_list': ['Drama', 'Music'], 'running_time': 110}
# {'key': 'tt0304141', 'title': 'Harry Potter and the Prisoner of Azkaban ', 'year': '2004', 'genre_list': ['Adventure', 'Family', 'Fantasy'], 'running_time': 142}
# {'key': 'tt0305711', 'title': 'Just Married ', 'year': '2003', 'genre_list': ['Comedy', 'Romance'], 'running_time': 95}
# {'key': 'tt0307987', 'title': 'Bad Santa ', 'year': '2003', 'genre_list': ['Comedy', 'Crime', 'Drama'], 'running_time': 91}
# {'key': 'tt0313542', 'title': 'Runaway Jury ', 'year': '2003', 'genre_list': ['Crime', 'Drama', 'Thriller'], 'running_time': 127}
# {'key': 'tt0314331', 'title': 'Love Actually ', 'year': '2003', 'genre_list': ['Comedy', 'Drama', 'Romance'], 'running_time': 135}
# {'key': 'tt0315327', 'title': 'Bruce Almighty ', 'year': '2003', 'genre_list': ['Comedy', 'Drama', 'Fantasy'], 'running_time': 101}
# {'key': 'tt0316654', 'title': 'Spider-Man 2 ', 'year': '2004', 'genre_list': ['Action', 'Adventure', 'Sci-Fi'], 'running_time': 127}
# {'key': 'tt0317198', 'title': 'Bridget Jonesui ilgi: Yeoljeong aejeong ', 'year': '2004', 'genre_list': ['Comedy', 'Drama', 'Romance'], 'running_time': 108}
# {'key': 'tt0319061', 'title': 'Big Fish ', 'year': '2003', 'genre_list': ['Adventure', 'Drama', 'Fantasy'], 'running_time': 125}
# {'key': 'tt0322259', 'title': '2 Fast 2 Furious ', 'year': '2003', 'genre_list': ['Action', 'Crime', 'Thriller'], 'running_time': 107}
# {'key': 'tt0324554', 'title': 'While You Were Falling in Love ', 'year': '2004', 'genre_list': ['Drama', 'Mystery', 'Romance'], 'running_time': 114}
# {'key': 'tt0325980', 'title': 'Pirates of the Caribbean: The Curse of the Black Pearl ', 'year': '2003', 'genre_list': ['Action', 'Adventure', 'Fantasy'], 'running_time': 143}
# {'key': 'tt0327597', 'title': 'Coraline ', 'year': '2009', 'genre_list': ['Animation', 'Drama', 'Fantasy'], 'running_time': 100}
# {'key': 'tt0328107', 'title': 'Man on Fire ', 'year': '2004', 'genre_list': ['Action', 'Crime', 'Drama'], 'running_time': 146}
# {'key': 'tt0330373', 'title': 'Harry Potter and the Goblet of Fire ', 'year': '2005', 'genre_list': ['Adventure', 'Family', 'Fantasy'], 'running_time': 157}
# {'key': 'tt0331811', 'title': '11:14 ', 'year': '2003', 'genre_list': ['Crime', 'Drama', 'Horror'], 'running_time': 86}
# {'key': 'tt0332452', 'title': 'Troy ', 'year': '2004', 'genre_list': ['Drama', 'History', 'Romance'], 'running_time': 163}
# {'key': 'tt0333780', 'title': 'Legally Blonde 2: Red, White & Blonde ', 'year': '2003', 'genre_list': ['Comedy'], 'running_time': 95}
# {'key': 'tt0335119', 'title': 'Jinju gwigeolireul han sonyeo ', 'year': '2003', 'genre_list': ['Biography', 'Drama', 'Romance'], 'running_time': 100}
# {'key': 'tt0335266', 'title': 'Lost in Translation ', 'year': '2003', 'genre_list': ['Drama'], 'running_time': 102}
# {'key': 'tt0337978', 'title': 'Live Free or Die Hard ', 'year': '2007', 'genre_list': ['Action', 'Adventure', 'Thriller'], 'running_time': 128}
# {'key': 'tt0343660', 'title': 'Cheotkisuman 50baenjjae ', 'year': '2004', 'genre_list': ['Comedy', 'Drama', 'Romance'], 'running_time': 99}
# {'key': 'tt0343818', 'title': 'I, Robot ', 'year': '2004', 'genre_list': ['Action', 'Adventure', 'Crime'], 'running_time': 115}
# {'key': 'tt0349903', 'title': "Ocean's Twelve ", 'year': '2004', 'genre_list': ['Crime', 'Thriller'], 'running_time': 125}
# {'key': 'tt0357413', 'title': 'Anchorman: The Legend of Ron Burgundy ', 'year': '2004', 'genre_list': ['Comedy'], 'running_time': 94}
# {'key': 'tt0359950', 'title': 'The Secret Life of Walter Mitty ', 'year': '2013', 'genre_list': ['Adventure', 'Comedy', 'Drama'], 'running_time': 114}
# {'key': 'tt0362269', 'title': 'Kinsey ', 'year': '2004', 'genre_list': ['Biography', 'Drama', 'Romance'], 'running_time': 118}
# {'key': 'tt0363771', 'title': 'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe ', 'year': '2005', 'genre_list': ['Adventure', 'Family', 'Fantasy'], 'running_time': 143}
# {'key': 'tt0365907', 'title': 'A Walk Among the Tombstones ', 'year': '2014', 'genre_list': ['Crime', 'Drama', 'Mystery'], 'running_time': 114}
# {'key': 'tt0367882', 'title': 'Indiana Jones and the Kingdom of the Crystal Skull ', 'year': '2008', 'genre_list': ['Action', 'Adventure', 'Fantasy'], 'running_time': 122}
# {'key': 'tt0372237', 'title': 'Guess Who ', 'year': '2005', 'genre_list': ['Comedy', 'Romance'], 'running_time': 105}
# {'key': 'tt0372784', 'title': 'Batman Begins ', 'year': '2005', 'genre_list': ['Action', 'Adventure'], 'running_time': 140}
# {'key': 'tt0373889', 'title': 'Harry Potter and the Order of the Phoenix ', 'year': '2007', 'genre_list': ['Adventure', 'Family', 'Fantasy'], 'running_time': 138}
# {'key': 'tt0375679', 'title': 'Crash ', 'year': '2004', 'genre_list': ['Crime', 'Drama', 'Thriller'], 'running_time': 112}
# {'key': 'tt0376994', 'title': 'X-Men: The Last Stand ', 'year': '2006', 'genre_list': ['Action', 'Adventure', 'Sci-Fi'], 'running_time': 104}
# {'key': 'tt0379786', 'title': 'Serenity ', 'year': '2005', 'genre_list': ['Action', 'Adventure', 'Sci-Fi'], 'running_time': 119}
# {'key': 'tt0381061', 'title': 'Casino Royale ', 'year': '2006', 'genre_list': ['Action', 'Adventure', 'Thriller'], 'running_time': 144}
# {'key': 'tt0382625', 'title': 'The Da Vinci Code ', 'year': '2006', 'genre_list': ['Mystery', 'Thriller'], 'running_time': 149}
# {'key': 'tt0383574', 'title': "Pirates of the Caribbean: Dead Man's Chest ", 'year': '2006', 'genre_list': ['Action', 'Adventure', 'Fantasy'], 'running_time': 151}
# {'key': 'tt0385752', 'title': 'The Golden Compass ', 'year': '2007', 'genre_list': ['Adventure', 'Family', 'Fantasy'], 'running_time': 113}
# {'key': 'tt0388795', 'title': 'Brokeback Mountain ', 'year': '2005', 'genre_list': ['Drama', 'Romance'], 'running_time': 134}
# {'key': 'tt0397078', 'title': 'Just My Luck ', 'year': '2006', 'genre_list': ['Comedy', 'Fantasy', 'Romance'], 'running_time': 103}
# {'key': 'tt0397535', 'title': 'Memoirs of a Geisha ', 'year': '2005', 'genre_list': ['Drama', 'Romance'], 'running_time': 145}
# {'key': 'tt0404203', 'title': 'Little Children ', 'year': '2006', 'genre_list': ['Drama', 'Romance'], 'running_time': 136}
# {'key': 'tt0408306', 'title': 'Munich ', 'year': '2005', 'genre_list': ['Drama', 'History', 'Thriller'], 'running_time': 164}
# {'key': 'tt0409847', 'title': 'Cowboys & Aliens ', 'year': '2011', 'genre_list': ['Action', 'Sci-Fi', 'Thriller'], 'running_time': 119}
# {'key': 'tt0410400', 'title': 'On a Clear Day ', 'year': '2005', 'genre_list': ['Comedy', 'Drama', 'Romance'], 'running_time': 95}
# {'key': 'tt0411061', 'title': '88 Minutes ', 'year': '2007', 'genre_list': ['Crime', 'Drama', 'Mystery'], 'running_time': 108}
# {'key': 'tt0412019', 'title': 'Broken Flowers ', 'year': '2005', 'genre_list': ['Comedy', 'Drama', 'Mystery'], 'running_time': 106}
# {'key': 'tt0414055', 'title': 'Elizabeth: The Golden Age ', 'year': '2007', 'genre_list': ['Biography', 'Drama', 'History'], 'running_time': 114}
# {'key': 'tt0416320', 'title': 'Match Point ', 'year': '2005', 'genre_list': ['Drama', 'Romance', 'Thriller'], 'running_time': 124}
# {'key': 'tt0417741', 'title': 'Harry Potter and the Half-Blood Prince ', 'year': '2009', 'genre_list': ['Adventure', 'Family', 'Fantasy'], 'running_time': 153}
# {'key': 'tt0418279', 'title': 'Transformers ', 'year': '2007', 'genre_list': ['Action', 'Adventure', 'Sci-Fi'], 'running_time': 144}
# {'key': 'tt0419887', 'title': 'The Kite Runner ', 'year': '2007', 'genre_list': ['Drama'], 'running_time': 128}
# {'key': 'tt0421715', 'title': 'The Curious Case of Benjamin Button ', 'year': '2008', 'genre_list': ['Drama', 'Fantasy', 'Romance'], 'running_time': 166}
# {'key': 'tt0425210', 'title': 'Lucky Number Slevin ', 'year': '2006', 'genre_list': ['Crime', 'Drama', 'Mystery'], 'running_time': 110}
# {'key': 'tt0427309', 'title': 'The Great Debaters ', 'year': '2007', 'genre_list': ['Biography', 'Drama', 'Romance'], 'running_time': 126}
# {'key': 'tt0433400', 'title': 'Just Friends ', 'year': '2005', 'genre_list': ['Comedy', 'Romance'], 'running_time': 96}
# {'key': 'tt0433416', 'title': 'The Namesake ', 'year': '2006', 'genre_list': ['Drama'], 'running_time': 122}
# {'key': 'tt0440963', 'title': 'The Bourne Ultimatum ', 'year': '2007', 'genre_list': ['Action', 'Mystery', 'Thriller'], 'running_time': 115}
# {'key': 'tt0441773', 'title': 'Kung Fu Panda ', 'year': '2008', 'genre_list': ['Animation', 'Action', 'Adventure'], 'running_time': 92}
# {'key': 'tt0443453', 'title': 'Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan ', 'year': '2006', 'genre_list': ['Comedy'], 'running_time': 84}
# {'key': 'tt0443706', 'title': 'Zodiac ', 'year': '2007', 'genre_list': ['Crime', 'Drama', 'History'], 'running_time': 157}
# {'key': 'tt0449088', 'title': "Pirates of the Caribbean: At World's End ", 'year': '2007', 'genre_list': ['Action', 'Adventure', 'Fantasy'], 'running_time': 169}
# {'key': 'tt0450259', 'title': 'Blood Diamond ', 'year': '2006', 'genre_list': ['Adventure', 'Drama', 'Thriller'], 'running_time': 143}
# {'key': 'tt0450385', 'title': '1408 ', 'year': '2007', 'genre_list': ['Drama', 'Horror'], 'running_time': 104}
# {'key': 'tt0452623', 'title': 'Gone Baby Gone ', 'year': '2007', 'genre_list': ['Crime', 'Drama', 'Mystery'], 'running_time': 114}
# {'key': 'tt0452625', 'title': 'Good Luck Chuck ', 'year': '2007', 'genre_list': ['Comedy', 'Fantasy', 'Romance'], 'running_time': 96}
# {'key': 'tt0454848', 'title': 'Inside Man ', 'year': '2006', 'genre_list': ['Crime', 'Drama', 'Mystery'], 'running_time': 129}
# {'key': 'tt0454921', 'title': 'The Pursuit of Happyness ', 'year': '2006', 'genre_list': ['Biography', 'Drama'], 'running_time': 117}
# {'key': 'tt0455824', 'title': 'Australia ', 'year': '2008', 'genre_list': ['Adventure', 'Drama', 'Romance'], 'running_time': 165}
# {'key': 'tt0457939', 'title': 'The Holiday ', 'year': '2006', 'genre_list': ['Comedy', 'Romance'], 'running_time': 138}
# {'key': 'tt0458352', 'title': 'The Devil Wears Prada ', 'year': '2006', 'genre_list': ['Comedy', 'Drama'], 'running_time': 109}
# {'key': 'tt0458525', 'title': 'Ekseumaen tansaeng - Ulbeorin ', 'year': '2009', 'genre_list': ['Action', 'Adventure', 'Sci-Fi'], 'running_time': 107}
# {'key': 'tt0467406', 'title': 'Juno ', 'year': '2007', 'genre_list': ['Comedy', 'Drama'], 'running_time': 96}
# {'key': 'tt0468569', 'title': 'The Dark Knight ', 'year': '2008', 'genre_list': ['Action', 'Crime', 'Drama'], 'running_time': 152}
# {'key': 'tt0469641', 'title': 'World Trade Center ', 'year': '2006', 'genre_list': ['Drama', 'History', 'Thriller'], 'running_time': 129}
# {'key': 'tt0475394', 'title': "Smokin' Aces ", 'year': '2006', 'genre_list': ['Action', 'Crime', 'Drama'], 'running_time': 109}
# {'key': 'tt0476964', 'title': 'The Brave One ', 'year': '2007', 'genre_list': ['Crime', 'Drama', 'Thriller'], 'running_time': 122}
# {'key': 'tt0478311', 'title': 'Knocked Up ', 'year': '2007', 'genre_list': ['Comedy', 'Romance'], 'running_time': 129}
# {'key': 'tt0480025', 'title': 'This Is England ', 'year': '2006', 'genre_list': ['Crime', 'Drama'], 'running_time': 101}
# {'key': 'tt0480242', 'title': 'Dan in Real Life ', 'year': '2007', 'genre_list': ['Comedy', 'Drama', 'Romance'], 'running_time': 98}
# {'key': 'tt0486822', 'title': 'Disturbia ', 'year': '2007', 'genre_list': ['Drama', 'Mystery', 'Thriller'], 'running_time': 105}
# {'key': 'tt0493464', 'title': 'Wanted ', 'year': '2008', 'genre_list': ['Action', 'Crime', 'Fantasy'], 'running_time': 110}
# {'key': 'tt0499549', 'title': 'Avatar ', 'year': '2009', 'genre_list': ['Action', 'Adventure', 'Fantasy'], 'running_time': 162}
# {'key': 'tt0758774', 'title': 'Body of Lies ', 'year': '2008', 'genre_list': ['Action', 'Drama', 'Romance'], 'running_time': 128}
# {'key': 'tt0765429', 'title': 'American Gangster ', 'year': '2007', 'genre_list': ['Biography', 'Crime', 'Drama'], 'running_time': 157}
# {'key': 'tt0780504', 'title': 'Drive ', 'year': '2011', 'genre_list': ['Crime', 'Drama'], 'running_time': 100}
# {'key': 'tt0780571', 'title': 'Mr. Brooks ', 'year': '2007', 'genre_list': ['Crime', 'Drama', 'Thriller'], 'running_time': 120}
# {'key': 'tt0790636', 'title': 'Dallas Buyers Club ', 'year': '2013', 'genre_list': ['Biography', 'Drama'], 'running_time': 117}
# {'key': 'tt0800039', 'title': 'Forgetting Sarah Marshall ', 'year': '2008', 'genre_list': ['Comedy', 'Drama', 'Romance'], 'running_time': 111}
# {'key': 'tt0800320', 'title': 'Clash of the Titans ', 'year': '2010', 'genre_list': ['Action', 'Adventure', 'Fantasy'], 'running_time': 106}
# {'key': 'tt0800369', 'title': 'Thor ', 'year': '2011', 'genre_list': ['Action', 'Adventure', 'Fantasy'], 'running_time': 115}
# {'key': 'tt0804522', 'title': 'Rendition ', 'year': '2007', 'genre_list': ['Drama', 'Thriller'], 'running_time': 122}
# {'key': 'tt0816436', 'title': 'Black Water ', 'year': '2007', 'genre_list': ['Action', 'Drama', 'Horror'], 'running_time': 90}
# {'key': 'tt0816692', 'title': 'Interstellar ', 'year': '2014', 'genre_list': ['Adventure', 'Drama', 'Sci-Fi'], 'running_time': 169}
# {'key': 'tt0822832', 'title': 'Marley & Me ', 'year': '2008', 'genre_list': ['Comedy', 'Drama', 'Family'], 'running_time': 115}
# {'key': 'tt0830570', 'title': "I Can't Think Straight ", 'year': '2008', 'genre_list': ['Drama', 'Romance'], 'running_time': 82}
# {'key': 'tt0866439', 'title': 'Made of Honor ', 'year': '2008', 'genre_list': ['Comedy', 'Romance'], 'running_time': 101}
# {'key': 'tt0887883', 'title': 'Burn After Reading ', 'year': '2008', 'genre_list': ['Comedy', 'Crime', 'Drama'], 'running_time': 96}
# {'key': 'tt0889583', 'title': 'Brüno ', 'year': '2009', 'genre_list': ['Comedy'], 'running_time': 81}
# {'key': 'tt0896872', 'title': 'The Whistleblower ', 'year': '2010', 'genre_list': ['Action', 'Biography', 'Crime'], 'running_time': 112}
# {'key': 'tt0898367', 'title': 'The Road ', 'year': '2009', 'genre_list': ['Adventure', 'Drama'], 'running_time': 111}
# {'key': 'tt0899106', 'title': 'Love Happens ', 'year': '2009', 'genre_list': ['Drama', 'Romance'], 'running_time': 109}
# {'key': 'tt0903624', 'title': 'The Hobbit: An Unexpected Journey ', 'year': '2012', 'genre_list': ['Adventure', 'Family', 'Fantasy'], 'running_time': 169}
# {'key': 'tt0907657', 'title': 'Once ', 'year': '2007', 'genre_list': ['Drama', 'Music', 'Romance'], 'running_time': 86}
# {'key': 'tt0910970', 'title': 'WALL·E ', 'year': '2008', 'genre_list': ['Animation', 'Adventure', 'Family'], 'running_time': 98}
# {'key': 'tt0914798', 'title': 'The Boy in the Striped Pyjamas ', 'year': '2008', 'genre_list': ['Drama', 'War'], 'running_time': 94}
# {'key': 'tt0926084', 'title': 'Harry Potter and the Deathly Hallows: Part 1 ', 'year': '2010', 'genre_list': ['Adventure', 'Family', 'Fantasy'], 'running_time': 146}
# {'key': 'tt0936501', 'title': 'Taken ', 'year': '2008', 'genre_list': ['Action', 'Crime', 'Thriller'], 'running_time': 93}
# {'key': 'tt0947798', 'title': 'Black Swan ', 'year': '2010', 'genre_list': ['Drama', 'Thriller'], 'running_time': 108}
# {'key': 'tt0959337', 'title': 'Revolutionary Road ', 'year': '2008', 'genre_list': ['Drama', 'Romance'], 'running_time': 119}
# {'key': 'tt0970416', 'title': 'The Day the Earth Stood Still ', 'year': '2008', 'genre_list': ['Drama', 'Sci-Fi', 'Thriller'], 'running_time': 104}
# {'key': 'tt0988595', 'title': '27 Dresses ', 'year': '2008', 'genre_list': ['Comedy', 'Romance'], 'running_time': 111}
# {'key': 'tt0993846', 'title': 'The Wolf of Wall Street ', 'year': '2013', 'genre_list': ['Biography', 'Comedy', 'Crime'], 'running_time': 180}
# {'key': 'tt1000774', 'title': 'Sex and the City ', 'year': '2008', 'genre_list': ['Comedy', 'Drama', 'Romance'], 'running_time': 145}
# {'key': 'tt1001508', 'title': "He's Just Not That Into You ", 'year': '2009', 'genre_list': ['Comedy', 'Drama', 'Romance'], 'running_time': 129}
# {'key': 'tt1010048', 'title': 'Slumdog Millionaire ', 'year': '2008', 'genre_list': ['Drama', 'Romance'], 'running_time': 120}
# {'key': 'tt1013753', 'title': 'Milk ', 'year': '2008', 'genre_list': ['Biography', 'Drama'], 'running_time': 128}
# {'key': 'tt1022603', 'title': '(500) Days of Summer ', 'year': '2009', 'genre_list': ['Comedy', 'Drama', 'Romance'], 'running_time': 95}
# {'key': 'tt1024648', 'title': 'Argo ', 'year': '2012', 'genre_list': ['Biography', 'Drama', 'Thriller'], 'running_time': 120}
# {'key': 'tt1033643', 'title': 'What Happens in Vegas ', 'year': '2008', 'genre_list': ['Comedy', 'Romance'], 'running_time': 99}
# {'key': 'tt1045658', 'title': 'Silver Linings Playbook ', 'year': '2012', 'genre_list': ['Comedy', 'Drama', 'Romance'], 'running_time': 122}
# {'key': 'tt1046173', 'title': 'G.I. Joe: The Rise of Cobra ', 'year': '2009', 'genre_list': ['Action', 'Adventure', 'Sci-Fi'], 'running_time': 118}
# {'key': 'tt1055369', 'title': 'Teuraenseupomeo: Paejaui Yeokseup ', 'year': '2009', 'genre_list': ['Action', 'Adventure', 'Sci-Fi'], 'running_time': 150}
# {'key': 'tt1058017', 'title': 'The Invention of Lying ', 'year': '2009', 'genre_list': ['Comedy', 'Fantasy', 'Romance'], 'running_time': 100}
# {'key': 'tt1065073', 'title': 'Boyhood ', 'year': '2014', 'genre_list': ['Drama'], 'running_time': 165}
# {'key': 'tt1068680', 'title': 'Yes Man ', 'year': '2008', 'genre_list': ['Comedy', 'Romance'], 'running_time': 104}
# {'key': 'tt1092026', 'title': 'Paul ', 'year': '2011', 'genre_list': ['Adventure', 'Comedy', 'Sci-Fi'], 'running_time': 104}
# {'key': 'tt1093908', 'title': 'Confessions of a Shopaholic ', 'year': '2009', 'genre_list': ['Comedy', 'Family', 'Romance'], 'running_time': 104}
# {'key': 'tt1099212', 'title': 'Twilight ', 'year': '2008', 'genre_list': ['Drama', 'Fantasy', 'Romance'], 'running_time': 122}
# {'key': 'tt1104001', 'title': 'Teuron: Saeroun Sijak ', 'year': '2010', 'genre_list': ['Action', 'Adventure', 'Sci-Fi'], 'running_time': 125}
# {'key': 'tt1114677', 'title': 'Hannah Montana: The Movie ', 'year': '2009', 'genre_list': ['Comedy', 'Drama', 'Family'], 'running_time': 102}
# {'key': 'tt1120985', 'title': 'Blue Valentine ', 'year': '2010', 'genre_list': ['Drama', 'Romance'], 'running_time': 112}
# {'key': 'tt1131734', 'title': "Jennifer's Body ", 'year': '2009', 'genre_list': ['Comedy', 'Horror'], 'running_time': 102}
# {'key': 'tt1133985', 'title': 'Geurillaenteon: Banjiui Seontaek ', 'year': '2011', 'genre_list': ['Action', 'Adventure', 'Sci-Fi'], 'running_time': 114}
# {'key': 'tt1139328', 'title': 'The Ghost Writer ', 'year': '2010', 'genre_list': ['Drama', 'Mystery', 'Thriller'], 'running_time': 128}
# {'key': 'tt1142988', 'title': 'The Ugly Truth ', 'year': '2009', 'genre_list': ['Comedy', 'Romance'], 'running_time': 96}
# {'key': 'tt1148204', 'title': 'Orphan ', 'year': '2009', 'genre_list': ['Horror', 'Mystery', 'Thriller'], 'running_time': 123}
# {'key': 'tt1170358', 'title': 'The Hobbit: The Desolation of Smaug ', 'year': '2013', 'genre_list': ['Adventure', 'Fantasy'], 'running_time': 161}
# {'key': 'tt1174732', 'title': 'An Education ', 'year': '2009', 'genre_list': ['Drama'], 'running_time': 100}
# {'key': 'tt1178663', 'title': 'Whatever Works ', 'year': '2009', 'genre_list': ['Comedy', 'Romance'], 'running_time': 93}
# {'key': 'tt1178665', 'title': 'A Walk in the Woods ', 'year': '2015', 'genre_list': ['Adventure', 'Biography', 'Comedy'], 'running_time': 104}
# {'key': 'tt1179031', 'title': 'Cold in July ', 'year': '2014', 'genre_list': ['Crime', 'Thriller'], 'running_time': 109}
# {'key': 'tt1182345', 'title': 'Moon ', 'year': '2009', 'genre_list': ['Drama', 'Mystery', 'Sci-Fi'], 'running_time': 97}
# {'key': 'tt1189340', 'title': 'Ringkeon Chareul Taneun Byeonhosa ', 'year': '2011', 'genre_list': ['Crime', 'Drama', 'Thriller'], 'running_time': 118}
# {'key': 'tt1190080', 'title': '2012 ', 'year': '2009', 'genre_list': ['Action', 'Adventure', 'Sci-Fi'], 'running_time': 158}
# {'key': 'tt1193138', 'title': 'Up in the Air ', 'year': '2009', 'genre_list': ['Drama', 'Romance'], 'running_time': 109}
# {'key': 'tt1197624', 'title': 'Law Abiding Citizen ', 'year': '2009', 'genre_list': ['Crime', 'Drama', 'Thriller'], 'running_time': 109}
# {'key': 'tt1201607', 'title': 'Haeri Poteowa jugeumui seongmul - 2bu ', 'year': '2011', 'genre_list': ['Adventure', 'Drama', 'Fantasy'], 'running_time': 130}
# {'key': 'tt1205489', 'title': 'Gran Torino ', 'year': '2008', 'genre_list': ['Drama'], 'running_time': 116}
# {'key': 'tt1228705', 'title': 'Iron Man 2 ', 'year': '2010', 'genre_list': ['Action', 'Adventure', 'Sci-Fi'], 'running_time': 124}
# {'key': 'tt1229340', 'title': 'Anchorman 2: The Legend Continues ', 'year': '2013', 'genre_list': ['Comedy'], 'running_time': 119}
# {'key': 'tt1229822', 'title': 'Jane Eyre ', 'year': '2011', 'genre_list': ['Drama', 'Romance'], 'running_time': 120}
# {'key': 'tt1232829', 'title': '21 Jump Street ', 'year': '2012', 'genre_list': ['Action', 'Comedy', 'Crime'], 'running_time': 109}
# {'key': 'tt1261945', 'title': 'Sex and the City 2 ', 'year': '2010', 'genre_list': ['Comedy', 'Drama', 'Romance'], 'running_time': 146}
# {'key': 'tt1270798', 'title': 'X: First Class ', 'year': '2011', 'genre_list': ['Action', 'Adventure', 'Sci-Fi'], 'running_time': 131}
# {'key': 'tt1272878', 'title': '2 Guns ', 'year': '2013', 'genre_list': ['Action', 'Comedy', 'Crime'], 'running_time': 109}
# {'key': 'tt1276104', 'title': 'Looper ', 'year': '2012', 'genre_list': ['Action', 'Crime', 'Drama'], 'running_time': 113}
# {'key': 'tt1284575', 'title': 'Bad Teacher ', 'year': '2011', 'genre_list': ['Comedy'], 'running_time': 92}
# {'key': 'tt1285016', 'title': 'Sosyeol neteuwokeu ', 'year': '2010', 'genre_list': ['Biography', 'Drama'], 'running_time': 120}
# {'key': 'tt1298650', 'title': 'Kaeribianui Haejeok - Natseon Joryu ', 'year': '2011', 'genre_list': ['Action', 'Adventure', 'Fantasy'], 'running_time': 136}
# {'key': 'tt1306980', 'title': '50/50 ', 'year': '2011', 'genre_list': ['Comedy', 'Drama', 'Romance'], 'running_time': 100}
# {'key': 'tt1322312', 'title': 'Going the Distance ', 'year': '2010', 'genre_list': ['Comedy', 'Romance'], 'running_time': 102}
# {'key': 'tt1323594', 'title': 'Despicable Me ', 'year': '2010', 'genre_list': ['Animation', 'Adventure', 'Comedy'], 'running_time': 95}
# {'key': 'tt1343092', 'title': 'The Great Gatsby ', 'year': '2013', 'genre_list': ['Drama', 'Romance'], 'running_time': 143}
# {'key': 'tt1345836', 'title': 'Dakeu naiteu raijeu ', 'year': '2012', 'genre_list': ['Action', 'Thriller'], 'running_time': 164}
# {'key': 'tt1371111', 'title': 'Cloud Atlas ', 'year': '2012', 'genre_list': ['Action', 'Drama', 'Mystery'], 'running_time': 172}
# {'key': 'tt1375666', 'title': 'Inception ', 'year': '2010', 'genre_list': ['Action', 'Adventure', 'Sci-Fi'], 'running_time': 148}
# {'key': 'tt1385826', 'title': 'Controller ', 'year': '2011', 'genre_list': ['Romance', 'Sci-Fi', 'Thriller'], 'running_time': 106}
# {'key': 'tt1399103', 'title': 'Teuraenseupomeo 3 ', 'year': '2011', 'genre_list': ['Action', 'Adventure', 'Sci-Fi'], 'running_time': 154}
# {'key': 'tt1401152', 'title': 'Unknown ', 'year': '2011', 'genre_list': ['Action', 'Mystery', 'Thriller'], 'running_time': 113}
# {'key': 'tt1409024', 'title': 'Men in Black 3 ', 'year': '2012', 'genre_list': ['Action', 'Adventure', 'Comedy'], 'running_time': 106}
# {'key': 'tt1446714', 'title': 'Peurometeuseu ', 'year': '2012', 'genre_list': ['Adventure', 'Mystery', 'Sci-Fi'], 'running_time': 124}
# {'key': 'tt1454029', 'title': 'The Help ', 'year': '2011', 'genre_list': ['Drama'], 'running_time': 146}
# {'key': 'tt1454468', 'title': 'Gravity ', 'year': '2013', 'genre_list': ['Drama', 'Sci-Fi', 'Thriller'], 'running_time': 91}
# {'key': 'tt1478338', 'title': 'Bridesmaids ', 'year': '2011', 'genre_list': ['Comedy', 'Romance'], 'running_time': 125}
# {'key': 'tt1483013', 'title': 'Oblivion ', 'year': '2013', 'genre_list': ['Action', 'Adventure', 'Mystery'], 'running_time': 124}
# {'key': 'tt1499658', 'title': 'Horrible Bosses ', 'year': '2011', 'genre_list': ['Comedy', 'Crime'], 'running_time': 98}
# {'key': 'tt1504320', 'title': "The King's Speech ", 'year': '2010', 'genre_list': ['Biography', 'Drama', 'History'], 'running_time': 118}
# {'key': 'tt1535970', 'title': 'The Ledge ', 'year': '2011', 'genre_list': ['Drama', 'Romance', 'Thriller'], 'running_time': 101}
# {'key': 'tt1542344', 'title': '127 Hours ', 'year': '2010', 'genre_list': ['Adventure', 'Biography', 'Drama'], 'running_time': 94}
# {'key': 'tt1568346', 'title': 'The Girl with the Dragon Tattoo ', 'year': '2011', 'genre_list': ['Crime', 'Drama', 'Mystery'], 'running_time': 158}
# {'key': 'tt1570728', 'title': 'Crazy, Stupid, Love. ', 'year': '2011', 'genre_list': ['Comedy', 'Drama', 'Romance'], 'running_time': 118}
# {'key': 'tt1598822', 'title': "New Year's Eve ", 'year': '2011', 'genre_list': ['Comedy', 'Romance'], 'running_time': 113}
# {'key': 'tt1605783', 'title': 'Midnight in Paris ', 'year': '2011', 'genre_list': ['Comedy', 'Fantasy', 'Romance'], 'running_time': 94}
# {'key': 'tt1615147', 'title': 'Margin Call ', 'year': '2011', 'genre_list': ['Drama', 'Thriller'], 'running_time': 107}
# {'key': 'tt1632708', 'title': 'Friends with Benefits ', 'year': '2011', 'genre_list': ['Comedy', 'Romance'], 'running_time': 109}
# {'key': 'tt1637725', 'title': 'Ted ', 'year': '2012', 'genre_list': ['Comedy', 'Fantasy'], 'running_time': 106}
# {'key': 'tt1646971', 'title': 'How to Train Your Dragon 2 ', 'year': '2014', 'genre_list': ['Animation', 'Action', 'Adventure'], 'running_time': 102}
# {'key': 'tt1659337', 'title': 'The Perks of Being a Wallflower ', 'year': '2012', 'genre_list': ['Drama', 'Romance'], 'running_time': 102}
# {'key': 'tt1675434', 'title': 'The Intouchables ', 'year': '2011', 'genre_list': ['Biography', 'Comedy', 'Drama'], 'running_time': 112}
# {'key': 'tt1686821', 'title': 'Vampire Academy ', 'year': '2014', 'genre_list': ['Action', 'Comedy', 'Fantasy'], 'running_time': 104}
# {'key': 'tt1692486', 'title': 'Carnage ', 'year': '2011', 'genre_list': ['Comedy', 'Drama'], 'running_time': 80}
# {'key': 'tt1706593', 'title': 'Chronicle ', 'year': '2012', 'genre_list': ['Drama', 'Sci-Fi', 'Thriller'], 'running_time': 84}
# {'key': 'tt1707386', 'title': 'Les Misérables ', 'year': '2012', 'genre_list': ['Drama', 'History', 'Musical'], 'running_time': 158}
# {'key': 'tt1725986', 'title': 'Some Kind of Beautiful ', 'year': '2014', 'genre_list': ['Comedy', 'Romance'], 'running_time': 99}
# {'key': 'tt1726592', 'title': 'Before I Go to Sleep ', 'year': '2014', 'genre_list': ['Drama', 'Horror', 'Mystery'], 'running_time': 92}
# {'key': 'tt1727770', 'title': 'Absolutely Anything ', 'year': '2015', 'genre_list': ['Comedy', 'Sci-Fi'], 'running_time': 85}
# {'key': 'tt1748122', 'title': 'Moonrise Kingdom ', 'year': '2012', 'genre_list': ['Adventure', 'Comedy', 'Drama'], 'running_time': 94}
# {'key': 'tt1758830', 'title': 'This Is 40 ', 'year': '2012', 'genre_list': ['Comedy', 'Romance'], 'running_time': 134}
# {'key': 'tt1781769', 'title': 'Anna Karenina ', 'year': '2012', 'genre_list': ['Drama', 'Romance'], 'running_time': 129}
# {'key': 'tt1790885', 'title': 'Zero Dark Thirty ', 'year': '2012', 'genre_list': ['Drama', 'Thriller'], 'running_time': 157}
# {'key': 'tt1798709', 'title': 'Geu-nyeo ', 'year': '2013', 'genre_list': ['Drama', 'Romance', 'Sci-Fi'], 'running_time': 126}
# {'key': 'tt1800241', 'title': 'American Hustle ', 'year': '2013', 'genre_list': ['Crime', 'Drama'], 'running_time': 138}
# {'key': 'tt1823672', 'title': 'Chappie ', 'year': '2015', 'genre_list': ['Action', 'Crime', 'Drama'], 'running_time': 120}
# {'key': 'tt1837562', 'title': 'A Royal Night Out ', 'year': '2015', 'genre_list': ['Comedy', 'Drama', 'Romance'], 'running_time': 97}
# {'key': 'tt1840309', 'title': 'Divergent ', 'year': '2014', 'genre_list': ['Adventure', 'Mystery', 'Sci-Fi'], 'running_time': 139}
# {'key': 'tt1853728', 'title': 'Django Unchained ', 'year': '2012', 'genre_list': ['Drama', 'Western'], 'running_time': 165}
# {'key': 'tt1877832', 'title': 'X-Men: Days of Future Past ', 'year': '2014', 'genre_list': ['Action', 'Adventure', 'Sci-Fi'], 'running_time': 132}
# {'key': 'tt1907668', 'title': 'Flight ', 'year': '2012', 'genre_list': ['Drama', 'Thriller'], 'running_time': 138}
# {'key': 'tt1951264', 'title': 'The Hunger Games: Catching Fire ', 'year': '2013', 'genre_list': ['Action', 'Adventure', 'Mystery'], 'running_time': 146}
# {'key': 'tt1979320', 'title': 'Rush ', 'year': '2013', 'genre_list': ['Action', 'Biography', 'Drama'], 'running_time': 123}
# {'key': 'tt1981115', 'title': 'Thor: The Dark World ', 'year': '2013', 'genre_list': ['Action', 'Adventure', 'Sci-Fi'], 'running_time': 112}
# {'key': 'tt2024544', 'title': '12 Years a Slave ', 'year': '2013', 'genre_list': ['Biography', 'Drama', 'History'], 'running_time': 134}
# {'key': 'tt2172934', 'title': '3 Days to Kill ', 'year': '2014', 'genre_list': ['Action', 'Drama', 'Thriller'], 'running_time': 117}
# {'key': 'tt2194499', 'title': 'About Time ', 'year': '2013', 'genre_list': ['Comedy', 'Drama', 'Fantasy'], 'running_time': 123}
# {'key': 'tt2267998', 'title': 'Gone Girl ', 'year': '2014', 'genre_list': ['Crime', 'Drama', 'Mystery'], 'running_time': 149}
# {'key': 'tt2278388', 'title': 'The Grand Budapest Hotel ', 'year': '2014', 'genre_list': ['Adventure', 'Comedy', 'Drama'], 'running_time': 99}
# {'key': 'tt2294449', 'title': '22 Jump Street ', 'year': '2014', 'genre_list': ['Action', 'Comedy', 'Crime'], 'running_time': 112}
# {'key': 'tt2294629', 'title': 'Gyeowool Wangguk ', 'year': '2013', 'genre_list': ['Animation', 'Adventure', 'Comedy'], 'running_time': 102}
# {'key': 'tt2310332', 'title': 'The Hobbit: The Battle of the Five Armies ', 'year': '2014', 'genre_list': ['Adventure', 'Fantasy'], 'running_time': 144}
# {'key': 'tt2334873', 'title': 'Blue Jasmine ', 'year': '2013', 'genre_list': ['Drama'], 'running_time': 98}
# {'key': 'tt2370248', 'title': 'Short Term 12 ', 'year': '2013', 'genre_list': ['Drama'], 'running_time': 96}
# {'key': 'tt2382396', 'title': 'Joe ', 'year': '2013', 'genre_list': ['Crime', 'Drama'], 'running_time': 117}
# {'key': 'tt2402927', 'title': 'Carol ', 'year': '2015', 'genre_list': ['Drama', 'Romance'], 'running_time': 118}
# {'key': 'tt2614684', 'title': '71: Tears of Belfast ', 'year': '2014', 'genre_list': ['Action', 'Drama', 'Thriller'], 'running_time': 99}
# {'key': 'tt2719848', 'title': 'Everest ', 'year': '2015', 'genre_list': ['Action', 'Adventure', 'Biography'], 'running_time': 121}
# {'key': 'tt2923316', 'title': 'American Heist ', 'year': '2014', 'genre_list': ['Action', 'Crime', 'Drama'], 'running_time': 94}
# {'key': 'tt3316960', 'title': 'Still Alice ', 'year': '2014', 'genre_list': ['Drama'], 'running_time': 101}
# {'key': 'tt3346224', 'title': 'Zipper ', 'year': '2015', 'genre_list': ['Drama', 'Thriller'], 'running_time': 112}

# %%
len(data_dict)
# Out:
# 408

# %%
list(data_dict.keys()) == keys_list
# Out:
# True

# %%
bigger_wrapper["data"] = data_dict
bigger_wrapper["genre_dictionary"] = list(set(genre_dict_list))

# %%
bigger_wrapper["genre_dictionary"]
# Out:
# ['Sci-Fi',
#  'Adventure',
#  'Western',
#  'Biography',
#  'Mystery',
#  'Crime',
#  'Romance',
#  'Family',
#  'History',
#  'Action',
#  'Drama',
#  'Thriller',
#  'Horror',
#  'Film-Noir',
#  'War',
#  'Animation',
#  'Fantasy',
#  'Music',
#  'Musical',
#  'Comedy']

# %%
len(bigger_wrapper["genre_dictionary"])
# Out:
# 20
